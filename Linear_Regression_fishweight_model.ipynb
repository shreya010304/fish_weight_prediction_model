# %%
import pandas as pd

# %%
df=pd.read_csv('Fish.csv')

# %%
data=df.copy()

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.sample(5)
# Out:
#     Species  Weight  Length1  Length2  Length3  Height   Width
# 66   Parkki   140.0     19.0     20.7     23.2  8.5376  3.2944
# 152   Smelt     9.9     11.3     11.8     13.1  2.2139  1.1659
# 37    Roach    78.0     17.5     18.8     21.2  5.5756  2.9044
# 46    Roach   140.0     21.0     22.5     25.0  6.5500  3.3250
# 139    Pike   770.0     44.8     48.0     51.2  7.6800  5.3760

# %%
df.shape
# Out:
# (159, 7)

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.rename(columns={'Length1':'Vertical','Length2':'Diagonal','Length3':'Cross'},inplace=True)

# %%
df
# Out:
#     Species  Weight  Vertical  Diagonal  Cross   Height   Width
# 0     Bream   242.0      23.2      25.4   30.0  11.5200  4.0200
# 1     Bream   290.0      24.0      26.3   31.2  12.4800  4.3056
# 2     Bream   340.0      23.9      26.5   31.1  12.3778  4.6961
# 3     Bream   363.0      26.3      29.0   33.5  12.7300  4.4555
# 4     Bream   430.0      26.5      29.0   34.0  12.4440  5.1340
# ..      ...     ...       ...       ...    ...      ...     ...
# 154   Smelt    12.2      11.5      12.2   13.4   2.0904  1.3936
# 155   Smelt    13.4      11.7      12.4   13.5   2.4300  1.2690
# 156   Smelt    12.2      12.1      13.0   13.8   2.2770  1.2558
# 157   Smelt    19.7      13.2      14.3   15.2   2.8728  2.0672
# 158   Smelt    19.9      13.8      15.0   16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Species   159 non-null    object
#  1   Weight    159 non-null    float64
#  2   Vertical  159 non-null    float64
#  3   Diagonal  159 non-null    float64
#  4   Cross     159 non-null    float64
#  5   Height    159 non-null    float64
#  6   Width     159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.describe().T
# Out:
#           count        mean         std     min        25%       50%  \
# Weight    159.0  398.326415  357.978317  0.0000  120.00000  273.0000
# Vertical  159.0   26.247170    9.996441  7.5000   19.05000   25.2000
# Diagonal  159.0   28.415723   10.716328  8.4000   21.00000   27.3000
# Cross     159.0   31.227044   11.610246  8.8000   23.15000   29.4000
# Height    159.0    8.970994    4.286208  1.7284    5.94480    7.7860
# Width     159.0    4.417486    1.685804  1.0476    3.38565    4.2485
#
#                75%       max
# Weight    650.0000  1650.000
# Vertical   32.7000    59.000
# Diagonal   35.5000    63.400
# Cross      39.6500    68.000
# Height     12.3659    18.957
# Width       5.5845     8.142

# %%
df.isnull().sum()
# Out:
# Species     0
# Weight      0
# Vertical    0
# Diagonal    0
# Cross       0
# Height      0
# Width       0
# dtype: int64

# %%
sp=df.Species.value_counts()
sp
# Out:
# Species
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: count, dtype: int64

# %%
sp=pd.DataFrame(sp)

# %%
sp
# Out:
#            count
# Species
# Perch         56
# Bream         35
# Roach         20
# Pike          17
# Smelt         14
# Parkki        11
# Whitefish      6

# %%
sp.T
# Out:
# Species  Perch  Bream  Roach  Pike  Smelt  Parkki  Whitefish
# count       56     35     20    17     14      11          6

# %%
import seaborn as sns
# Assuming you already have sp as a dataframe with 2 columns: Species, count
sns.barplot(x="Species", y="count", data=sp,palette="pastel")
# Out:
# C:\Users\bhand\AppData\Local\Temp\ipykernel_32320\1230547341.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Species", y="count", data=sp,palette="pastel")
# <Axes: xlabel='Species', ylabel='count'>

# %%
df.corr(numeric_only=True)
# Out:
#             Weight  Vertical  Diagonal     Cross    Height     Width
# Weight    1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Vertical  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Diagonal  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Cross     0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height    0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width     0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
g=sns.pairplot(df,kind='scatter',hue='Species')

# %%
sns.boxplot(x=df.Weight)
# Out:
# <Axes: xlabel='Weight'>

# %%
df=df[df.Weight<=1500]

# %%
sns.boxplot(x=df.Weight)
# Out:
# <Axes: xlabel='Weight'>

# %%
df.shape
# Out:
# (156, 7)

# %%
df.Weight
# Out:
# 0      242.0
# 1      290.0
# 2      340.0
# 3      363.0
# 4      430.0
#        ...
# 154     12.2
# 155     13.4
# 156     12.2
# 157     19.7
# 158     19.9
# Name: Weight, Length: 156, dtype: float64

# %%
y=df.Weight

# %%
y
# Out:
# 0      242.0
# 1      290.0
# 2      340.0
# 3      363.0
# 4      430.0
#        ...
# 154     12.2
# 155     13.4
# 156     12.2
# 157     19.7
# 158     19.9
# Name: Weight, Length: 156, dtype: float64

# %%
X=df.iloc[:,2:7]
X
# Out:
#      Vertical  Diagonal  Cross   Height   Width
# 0        23.2      25.4   30.0  11.5200  4.0200
# 1        24.0      26.3   31.2  12.4800  4.3056
# 2        23.9      26.5   31.1  12.3778  4.6961
# 3        26.3      29.0   33.5  12.7300  4.4555
# 4        26.5      29.0   34.0  12.4440  5.1340
# ..        ...       ...    ...      ...     ...
# 154      11.5      12.2   13.4   2.0904  1.3936
# 155      11.7      12.4   13.5   2.4300  1.2690
# 156      12.1      13.0   13.8   2.2770  1.2558
# 157      13.2      14.3   15.2   2.8728  2.0672
# 158      13.8      15.0   16.2   2.9322  1.8792
#
# [156 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (124, 5)

# %%
X_test.shape
# Out:
# (32, 5)

# %%
y_train.shape
# Out:
# (124,)

# %%
y_test.shape
# Out:
# (32,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(-421.0251325904579)

# %%
model.coef_
# Out:
# array([109.74536619, -42.89218633, -44.49850545,  38.98315847,
#         42.3072201 ])

# %%
import joblib

# %%
joblib.dump(model,"fish_weight_prediction.pkl")
# Out:
# ['fish_weight_prediction.pkl']

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([ 791.15571809,  229.65800275,   92.16573819,  541.103806  ,
#          90.00894574,  522.8905674 ,  778.75713717,  442.40280112,
#         160.15512444,  129.32751491,  -68.84586046,  359.26067663,
#         270.46087939,  357.18070363,  166.88816476,  212.5210232 ,
#         690.57677546,  283.06016801,  623.39519833,  704.01337046,
#        -141.47845944,  587.85995083,  588.8215888 ,  334.60326087,
#         880.70036399,  288.08416461,  672.99135529,  652.0015695 ,
#        -138.06833119,  293.60016456,  723.88331058,  820.8121068 ])

# %%
y_pred=pd.DataFrame(y_pred,columns=["Predicted Weight"])

# %%
y_pred.head()
# Out:
#    Predicted Weight
# 0        791.155718
# 1        229.658003
# 2         92.165738
# 3        541.103806
# 4         90.008946

# %%
y_test=pd.DataFrame(y_test)

# %%
y_test.head()
# Out:
#     Weight
# 29  1000.0
# 65   150.0
# 78    78.0
# 13   340.0
# 37    78.0

# %%
y_test=y_test.reset_index(drop=True)

# %%
y_test.head()
# Out:
#    Weight
# 0  1000.0
# 1   150.0
# 2    78.0
# 3   340.0
# 4    78.0

# %%
y_output=pd.concat([y_test,y_pred],axis=1)
y_output.head()
# Out:
#    Weight  Predicted Weight
# 0  1000.0        791.155718
# 1   150.0        229.658003
# 2    78.0         92.165738
# 3   340.0        541.103806
# 4    78.0         90.008946

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.88006170620093

# %%
X_train.head(2)
# Out:
#      Vertical  Diagonal  Cross   Height   Width
# 126      40.2      43.5   46.0  12.6040  8.1420
# 119      36.9      40.0   42.3  11.9286  7.1064

# %%
import numpy as np
new_data=np.array([[23,25,30,11,4]])
prediction=model.predict(new_data)
prediction
# Out:
# C:\Users\bhand\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([293.90209178])

# %%
print("Enter the values for fish pridiction:")
vertical=int(input("Enter the fish's vertical value"))
diagonal=int(input("Enter the fish's diagonal value"))
cross=int(input("Enter the fish's cross value"))
height=int(input("Enter the fish's height value"))
width=int(input("Enter the fish's width value"))
predicted_weight=model.predict([[vertical,diagonal,cross,height,width]])
print("The predicted weight is",predicted_weight)
# Out:
# Enter the values for fish pridiction:
# Enter the fish's vertical value 23
# Enter the fish's diagonal value 25
# Enter the fish's cross value 30
# Enter the fish's height value 11
# Enter the fish's width value 4
# The predicted weight is [293.90209178]
# C:\Users\bhand\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
